# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)
ax1.plot(np.random.standard_normal(50).cumsum(),color='black',linestyle="dashed")
ax2.hist(np.random.standard_normal(100),bins=20,color='black',alpha=0.3)
ax3.scatter(np.arange(30),np.arange(30)+3*np.random.standard_normal(30))
ax4.bar(['A','B','C','D'],[10,20,30,40])
# Out:
# <BarContainer object of 4 artists>

# %%
fig,axes=plt.subplots(2,2,sharex=True,sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.standard_normal(500),bins=50,color='black',alpha=0.5)
fig.subplots_adjust(wspace=0,hspace=0)

# %%
fig=plt.figure()
ax=fig.add_subplot()
ax.plot(np.random.standard_normal(1000).cumsum());
ticks=ax.set_xticks([0,250,500,750,1000])
labels=ax.set_xticklabels(["one","two","three","four","five"],rotation=30,fontsize=10)
ax.set_title("My plot")
ax.text(x=10,y=10,s="hello world!",family='monospace',fontsize=10)
# Out:
# Text(10, 10, 'hello world!')

# %%
# plt.rc("figure",figsize=(10,10))
plt.rc("font",family="monospace",weight='bold',size=8)
# plt.rcdefaults()

# %%
fig=plt.figure()
ax=fig.add_subplot()
ax.plot(np.random.standard_normal(1000).cumsum());
ticks=ax.set_xticks([0,250,500,750,1000])
labels=ax.set_xticklabels(["one","two","three","four","five"],rotation=30,fontsize=10)
ax.set_title("My plot")
ax.text(x=10,y=10,s="hello world!",family='monospace',fontsize=10);

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.arange(1,6)
y=x*2
data=np.random.randn(100)

fig,axs=plt.subplots(2,2,figsize=(6,4))

axs[0,0].plot(x,y)
axs[0,0].set_title("Line Pot")

axs[0,1].bar(x,y)
axs[0,1].set_title("Bar chart")

axs[1,0].hist(data)
axs[1,0].set_title("Histogram")

axs[1,1].scatter(x,y)
axs[1,1].set_title("Scatter Pot")

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
df=pd.read_csv('tips.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   gender      244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB
# None

# %%
sns.boxplot(
    x='gender',y='total_bill',data=df
)
plt.title("Total bill by gender");
plt.savefig('total Bill by gender.pdf')

# %%
sns.pairplot(df,hue='gender');

# %%
numerical_col=df.select_dtypes(include='number')

sns.heatmap(
    numerical_col.corr(),annot=True,cmap="coolwarm"
);

# %%
#web ko lagi plotly use grane
import plotly.express as px
import pandas as pd

df=px.scatter(df,x="sepal_length",y="sepal_width",color='species')

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 5
#       2 import plotly.express as px
#       3 import pandas as pd
# ----> 5 df=px.scatter(df,x="sepal_length",y="sepal_width",color='species')
#       7 fig.show()
#
# ...

# %%
fig=px.bar(df,x='species',y='sepal_length')

fig.show()

fig.write_html("plot.html")
