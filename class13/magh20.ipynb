# %%
import numpy as np
import pandas as pd
x=np.array([10,20,30,4000])

df=pd.DataFrame({'X':x})

print("Kurtosis of X column",df['X'].kurt())
# Out:
# Kurtosis of X column 3.9996633187929866

# %%
import numpy as np
import pandas as pd
x=np.array([10,20,30,50])

df=pd.DataFrame({'X':x})

print("Kurtosis of X column",df['X'].kurt())
# Out:
# Kurtosis of X column 0.3428571428571434

# %%
X=np.random.random(2000)
df=pd.DataFrame({'X':x})
print('Kurtosis of X column',df['X'].kurt())
# Out:
# Kurtosis of X column 0.3428571428571434
