# %%
# List of numbers
numbers = [1, 2, 3, 4, 5]

# Using a for loop to print square of each number
for num in numbers:
    print(num, "squared is", num**2)
# Out:
# 1 squared is 1
# 2 squared is 4
# 3 squared is 9
# 4 squared is 16
# 5 squared is 25
