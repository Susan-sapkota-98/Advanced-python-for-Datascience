# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm

# %%
X=np.arange(0,30,0.277)
y=0.9912*X+0.7734

# %%
split = int(len(X)*0.8)
X_train, y_train = X[:split], y[:split]
X_test, y_test = X[split:],y[split:]

# %%
#summary
model=sm.OLS(y_train,X_train).fit()
print(model.summary)
# Out:
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x734d5d4a6530>>

# %%
#multiple linear regression model
# create predictors with matching length
n = 300
X1 = np.linspace(0, 30, n)
X2 = np.linspace(1, 25, n)
y = 9.9912*X1 + 5.555*X2 + 4.7734
df = pd.DataFrame({
    'X1': X1, 'X2': X2, 'y': y
})
X = df.drop(columns='y')
y = df['y']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
#Add constant for statsmodels
X_train_sm=sm.add_constant(X_train)
X_test_sm=sm.add_constant(X_test)

#summary
model=
